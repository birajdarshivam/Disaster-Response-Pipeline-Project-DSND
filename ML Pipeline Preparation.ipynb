# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries


import re
import nltk
nltk.download(['punkt', 'wordnet'])
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.multioutput import MultiOutputClassifier
import pickle
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# load data from database
engine = create_engine('sqlite:///ETL_Preparation.db')
df = pd.read_sql_table('ETL', engine)
X = df.message
y = df[df.columns[4:]]
category_names = y.columns

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    url_regx = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
    detected_urls = re.findall(url_regx, text)
    for url in detected_urls:
        text = text.replace(url, "urlplaceholder")
        
    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()
    
    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
pipeline = Pipeline([
    ('vect', CountVectorizer(tokenizer = tokenize)),
    ('tfidf', TfidfTransformer()),
    ('clf',  MultiOutputClassifier(RandomForestClassifier()))
])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=1))])

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
y_pred = pipeline.predict(X_test)

for i in range(36):
    print(y_test.columns[i], ':')
    print(classification_report(y_test.iloc[:,i], y_pred[:,i], target_names=category_names), '...................................................')
# Out:
# related :
#                         precision    recall  f1-score   support
#
#                related       0.37      0.20      0.26       902
#                request       0.64      0.81      0.72      1625
#                  offer       0.00      0.00      0.00        29
#
#            avg / total       0.54      0.59      0.55      2556
#  ...................................................
# request :
#                         precision    recall  f1-score   support
#
#                related       0.68      0.88      0.77      1714
#                request       0.39      0.15      0.22       842
#
#            avg / total       0.58      0.64      0.59      2556
#  ...................................................
# offer :
#                         precision    recall  f1-score   support
#
#                related       1.00      1.00      1.00      2554
#                request       0.00      0.00      0.00         2
#
#            avg / total       1.00      1.00      1.00      2556
#  ...................................................
# aid_related :
#                         precision    recall  f1-score   support
#
#                related       0.64      0.85      0.73      1594
#                request       0.45      0.20      0.27       962
#
#            avg / total       0.57      0.61      0.56      2556
#  ...................................................
# medical_help :
#                         precision    recall  f1-score   support
#
#                related       0.95      1.00      0.97      2425
#                request       0.00      0.00      0.00       131
#
#            avg / total       0.90      0.95      0.92      2556
#  ...................................................
# medical_products :
#                         precision    recall  f1-score   support
#
#                related       0.97      1.00      0.98      2473
#                request       0.00      0.00      0.00        83
#
#            avg / total       0.94      0.97      0.95      2556
#  ...................................................
# search_and_rescue :
#                         precision    recall  f1-score   support
#
#                related       0.98      1.00      0.99      2496
#                request       0.00      0.00      0.00        60
#
#            avg / total       0.95      0.98      0.96      2556
#  ...................................................
# security :
#                         precision    recall  f1-score   support
#
#                related       0.99      1.00      0.99      2523
#                request       0.00      0.00      0.00        33
#
#            avg / total       0.97      0.99      0.98      2556
#  ...................................................
# military :
#                         precision    recall  f1-score   support
#
#                related       1.00      1.00      1.00      2548
#                request       0.00      0.00      0.00         8
#
#            avg / total       0.99      1.00      1.00      2556
#  ...................................................
# child_alone :
#                         precision    recall  f1-score   support
#
#                related       1.00      1.00      1.00      2556
#
#            avg / total       1.00      1.00      1.00      2556
#  ...................................................
# water :
#                         precision    recall  f1-score   support
#
#                related       0.93      1.00      0.96      2367
#                request       0.00      0.00      0.00       189
#
#            avg / total       0.86      0.92      0.89      2556
#  ...................................................
# food :
#                         precision    recall  f1-score   support
#
#                related       0.86      0.99      0.92      2209
#                request       0.08      0.01      0.01       347
#
#            avg / total       0.76      0.86      0.80      2556
#  ...................................................
# shelter :
#                         precision    recall  f1-score   support
#
#                related       0.89      0.99      0.94      2274
#                request       0.14      0.01      0.02       282
#
#            avg / total       0.81      0.88      0.84      2556
#  ...................................................
# clothing :
#                         precision    recall  f1-score   support
#
#                related       0.99      1.00      1.00      2532
#                request       0.00      0.00      0.00        24
#
#            avg / total       0.98      0.99      0.99      2556
#  ...................................................
# money :
#                         precision    recall  f1-score   support
#
#                related       0.99      1.00      1.00      2531
#                request       0.00      0.00      0.00        25
#
#            avg / total       0.98      0.99      0.99      2556
#  ...................................................
# missing_people :
#                         precision    recall  f1-score   support
#
#                related       0.99      1.00      0.99      2523
#                request       0.00      0.00      0.00        33
#
#            avg / total       0.97      0.99      0.98      2556
#  ...................................................
# refugees :
#                         precision    recall  f1-score   support
#
#                related       0.98      1.00      0.99      2516
#                request       0.00      0.00      0.00        40
#
#            avg / total       0.97      0.98      0.98      2556
#  ...................................................
# death :
#                         precision    recall  f1-score   support
#
#                related       0.97      1.00      0.99      2492
#                request       0.00      0.00      0.00        64
#
#            avg / total       0.95      0.97      0.96      2556
#  ...................................................
# other_aid :
#                         precision    recall  f1-score   support
#
#                related       0.87      0.99      0.92      2215
#                request       0.12      0.01      0.02       341
#
#            avg / total       0.77      0.86      0.80      2556
#  ...................................................
# infrastructure_related :
#                         precision    recall  f1-score   support
#
#                related       0.98      1.00      0.99      2494
#                request       0.00      0.00      0.00        62
#
#            avg / total       0.95      0.98      0.96      2556
#  ...................................................
# transport :
#                         precision    recall  f1-score   support
#
#                related       0.98      1.00      0.99      2502
#                request       0.00      0.00      0.00        54
#
#            avg / total       0.96      0.98      0.97      2556
#  ...................................................
# buildings :
#                         precision    recall  f1-score   support
#
#                related       0.96      1.00      0.98      2456
#                request       0.20      0.01      0.02       100
#
#            avg / total       0.93      0.96      0.94      2556
#  ...................................................
# electricity :
#                         precision    recall  f1-score   support
#
#                related       1.00      1.00      1.00      2544
#                request       0.00      0.00      0.00        12
#
#            avg / total       0.99      1.00      0.99      2556
#  ...................................................
# tools :
#                         precision    recall  f1-score   support
#
#                related       1.00      1.00      1.00      2548
#                request       0.00      0.00      0.00         8
#
#            avg / total       0.99      1.00      1.00      2556
#  ...................................................
# hospitals :
#                         precision    recall  f1-score   support
#
#                related       0.99      1.00      1.00      2543
#                request       0.00      0.00      0.00        13
#
#            avg / total       0.99      0.99      0.99      2556
#  ...................................................
# shops :
#                         precision    recall  f1-score   support
#
#                related       1.00      1.00      1.00      2551
#                request       0.00      0.00      0.00         5
#
#            avg / total       1.00      1.00      1.00      2556
#  ...................................................
# aid_centers :
#                         precision    recall  f1-score   support
#
#                related       0.99      1.00      1.00      2542
#                request       0.00      0.00      0.00        14
#
#            avg / total       0.99      0.99      0.99      2556
#  ...................................................
# other_infrastructure :
#                         precision    recall  f1-score   support
#
#                related       0.99      1.00      0.99      2521
#                request       0.00      0.00      0.00        35
#
#            avg / total       0.97      0.99      0.98      2556
#  ...................................................
# weather_related :
#                         precision    recall  f1-score   support
#
#                related       0.86      0.98      0.92      2193
#                request       0.23      0.04      0.06       363
#
#            avg / total       0.77      0.85      0.79      2556
#  ...................................................
# floods :
#                         precision    recall  f1-score   support
#
#                related       0.97      1.00      0.98      2484
#                request       0.17      0.01      0.03        72
#
#            avg / total       0.95      0.97      0.96      2556
#  ...................................................
# storm :
#                         precision    recall  f1-score   support
#
#                related       0.97      1.00      0.99      2488
#                request       0.25      0.01      0.03        68
#
#            avg / total       0.95      0.97      0.96      2556
#  ...................................................
# fire :
#                         precision    recall  f1-score   support
#
#                related       1.00      1.00      1.00      2544
#                request       0.00      0.00      0.00        12
#
#            avg / total       0.99      1.00      0.99      2556
#  ...................................................
# earthquake :
#                         precision    recall  f1-score   support
#
#                related       0.92      1.00      0.96      2355
#                request       0.09      0.00      0.01       201
#
#            avg / total       0.86      0.92      0.88      2556
#  ...................................................
# cold :
#                         precision    recall  f1-score   support
#
#                related       0.99      1.00      1.00      2539
#                request       0.00      0.00      0.00        17
#
#            avg / total       0.99      0.99      0.99      2556
#  ...................................................
# other_weather :
#                         precision    recall  f1-score   support
#
#                related       0.98      1.00      0.99      2511
#                request       0.00      0.00      0.00        45
#
#            avg / total       0.97      0.98      0.97      2556
#  ...................................................
# direct_report :
#                         precision    recall  f1-score   support
#
#                related       0.68      0.89      0.77      1739
#                request       0.34      0.13      0.18       817
#
#            avg / total       0.57      0.64      0.58      2556
#  ...................................................
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 3, does not match size of target_names, 36
#   .format(len(labels), len(target_names))
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 2, does not match size of target_names, 36
#   .format(len(labels), len(target_names))
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 1, does not match size of target_names, 36
#   .format(len(labels), len(target_names))

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('vect',
#    CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#            dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#            lowercase=True, max_df=1.0, max_features=None, min_df=1,
#            ngram_range=(1, 1), preprocessor=None, stop_words=None,
#            strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#            tokenizer=<function tokenize at 0x7fd598744620>, vocabulary=None)),
#   ('tfidf',
#    TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)),
#   ('clf',
#    MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                max_depth=None, max_features='auto', max_leaf_nodes=None,
#                min_impurity_decrease=0.0, min_impurity_split=None,
#                min_samples_leaf=1, min_samples_split=2,
#                min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#                oob_score=False, random_state=None, verbose=0,
#                warm_start=False),
#               n_jobs=1))],
#  'vect': CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#          dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#          lowercase=True, max_df=1.0, max_features=None, min_df=1,
#          ngram_range=(1, 1), preprocessor=None, stop_words=None,
#          strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#          tokenizer=<function tokenize at 0x7fd598744620>, vocabulary=None),
#  'tfidf': TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True),
#  'clf': MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#              oob_score=False, random_state=None, verbose=0,
#              warm_start=False),
#             n_jobs=1),
#  'vect__analyzer': 'word',
#  'vect__binary': False,
#  'vect__decode_error': 'strict',
#  'vect__dtype': numpy.int64,
#  'vect__encoding': 'utf-8',
#  'vect__input': 'content',
#  'vect__lowercase': True,
#  'vect__max_df': 1.0,
#  'vect__max_features': None,
#  'vect__min_df': 1,
#  'vect__ngram_range': (1, 1),
#  'vect__preprocessor': None,
#  'vect__stop_words': None,
#  'vect__strip_accents': None,
#  'vect__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'vect__tokenizer': <function __main__.tokenize(text)>,
#  'vect__vocabulary': None,
#  'tfidf__norm': 'l2',
#  'tfidf__smooth_idf': True,
#  'tfidf__sublinear_tf': False,
#  'tfidf__use_idf': True,
#  'clf__estimator__bootstrap': True,
#  'clf__estimator__class_weight': None,
#  'clf__estimator__criterion': 'gini',
#  'clf__estimator__max_depth': None,
#  'clf__estimator__max_features': 'auto',
#  'clf__estimator__max_leaf_nodes': None,
#  'clf__estimator__min_impurity_decrease': 0.0,
#  'clf__estimator__min_impurity_split': None,
#  'clf__estimator__min_samples_leaf': 1,
#  'clf__estimator__min_samples_split': 2,
#  'clf__estimator__min_weight_fraction_leaf': 0.0,
#  'clf__estimator__n_estimators': 10,
#  'clf__estimator__n_jobs': 1,
#  'clf__estimator__oob_score': False,
#  'clf__estimator__random_state': None,
#  'clf__estimator__verbose': 0,
#  'clf__estimator__warm_start': False,
#  'clf__estimator': RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#              oob_score=False, random_state=None, verbose=0,
#              warm_start=False),
#  'clf__n_jobs': 1}

# %%
parameters = {
    #'vect__ngram_range': ((1, 1),(1,2)),
    #'vect__max_df': (0.5, 0.75, 1.0),
    #'vect__max_features': (None, 5000, 10000),
    #'tfidf__use_idf': (True, False),
    'clf__estimator__n_estimators': [50, 100, 150],
    'clf__estimator__min_samples_split': [2, 3, 4],
    }
cv = GridSearchCV(pipeline, param_grid=parameters, n_jobs=4, verbose=2)

# %%
#MultiOutputClassifier(KNeighborsClassifier()).fit(X, y)
cv.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=50
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=50
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=50
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=50, total= 3.2min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=50, total= 3.3min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=50, total= 3.3min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=150
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, total= 6.4min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=150
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, total= 6.3min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=150
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, total= 6.3min
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=50
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=50, total= 3.0min
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=50
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=150, total= 9.5min
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=50
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=150, total= 9.3min
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=100
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=50, total= 2.9min
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=100
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=50, total= 2.9min
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=100
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=150, total= 9.3min
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=150
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=100, total= 5.6min
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=150
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=100, total= 5.5min
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=150
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=100, total= 5.6min
# [CV] clf__estimator__min_samples_split=4, clf__estimator__n_estimators=50
# [CV]  clf__estimator__min_samples_split=4, clf__estimator__n_estimators=50, total= 2.8min
# [CV] clf__estimator__min_samples_split=4, clf__estimator__n_estimators=50
# [CV]  clf__estimator__min_samples_split=4, clf__estimator__n_estimators=50, total= 2.9min
# [CV] clf__estimator__min_samples_split=4, clf__estimator__n_estimators=50
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=150, total= 8.6min
# [CV] clf__estimator__min_samples_split=4, clf__estimator__n_estimators=100
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=150, total= 8.4min
# [CV] clf__estimator__min_samples_split=4, clf__estimator__n_estimators=100
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=150, total= 8.5min
# [CV] clf__estimator__min_samples_split=4, clf__estimator__n_estimators=100
# [CV]  clf__estimator__min_samples_split=4, clf__estimator__n_estimators=50, total= 2.8min
# [CV] clf__estimator__min_samples_split=4, clf__estimator__n_estimators=150
# [CV]  clf__estimator__min_samples_split=4, clf__estimator__n_estimators=100, total= 5.3min
# [CV] clf__estimator__min_samples_split=4, clf__estimator__n_estimators=150
# [CV]  clf__estimator__min_samples_split=4, clf__estimator__n_estimators=100, total= 5.3min
# [CV] clf__estimator__min_samples_split=4, clf__estimator__n_estimators=150
# [CV]  clf__estimator__min_samples_split=4, clf__estimator__n_estimators=100, total= 5.3min
# [CV]  clf__estimator__min_samples_split=4, clf__estimator__n_estimators=150, total= 7.2min
# [CV]  clf__estimator__min_samples_split=4, clf__estimator__n_estimators=150, total= 6.0min
# [CV]  clf__estimator__min_samples_split=4, clf__estimator__n_estimators=150, total= 4.4min
# [Parallel(n_jobs=4)]: Done  27 out of  27 | elapsed: 43.3min finished
# GridSearchCV(cv=None, error_score='raise',
#        estimator=Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=1))]),
#        fit_params=None, iid=True, n_jobs=4,
#        param_grid={'clf__estimator__n_estimators': [50, 100, 150], 'clf__estimator__min_samples_split': [2, 3, 4]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=2)

# %%
cv.grid_scores_
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/model_selection/_search.py:761: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# [mean: 0.15156, std: 0.00832, params: {'clf__estimator__min_samples_split': 2, 'clf__estimator__n_estimators': 50},
#  mean: 0.15651, std: 0.00971, params: {'clf__estimator__min_samples_split': 2, 'clf__estimator__n_estimators': 100},
#  mean: 0.15743, std: 0.00815, params: {'clf__estimator__min_samples_split': 2, 'clf__estimator__n_estimators': 150},
#  mean: 0.14817, std: 0.00661, params: {'clf__estimator__min_samples_split': 3, 'clf__estimator__n_estimators': 50},
#  mean: 0.15573, std: 0.00941, params: {'clf__estimator__min_samples_split': 3, 'clf__estimator__n_estimators': 100},
#  mean: 0.15873, std: 0.00874, params: {'clf__estimator__min_samples_split': 3, 'clf__estimator__n_estimators': 150},
#  mean: 0.15208, std: 0.00259, params: {'clf__estimator__min_samples_split': 4, 'clf__estimator__n_estimators': 50},
#  mean: 0.15325, std: 0.00288, params: {'clf__estimator__min_samples_split': 4, 'clf__estimator__n_estimators': 100},
#  mean: 0.15678, std: 0.00755, params: {'clf__estimator__min_samples_split': 4, 'clf__estimator__n_estimators': 150}]

# %%
#finding the best paramesters based on grip search
print(cv.best_params_)
# Out:
# {'clf__estimator__min_samples_split': 3, 'clf__estimator__n_estimators': 150}

# %%
#building new model
optimised_model = cv.best_estimator_
print (cv.best_estimator_)
# Out:
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=1))])

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
y_pred = optimised_model.predict(X_test)

for i in range(36):
    print(y_test.columns[i], ':')
    print(classification_report(y_test.iloc[:,i], y_pred[:,i]), '================================================')
# Out:
# related :
#              precision    recall  f1-score   support
#
#         0.0       0.40      0.04      0.08       902
#         1.0       0.64      0.96      0.77      1625
#         2.0       0.00      0.00      0.00        29
#
# avg / total       0.55      0.63      0.52      2556
#  ================================================
# request :
#              precision    recall  f1-score   support
#
#         0.0       0.69      0.94      0.79      1714
#         1.0       0.51      0.13      0.20       842
#
# avg / total       0.63      0.67      0.60      2556
#  ================================================
# offer :
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      2554
#         1.0       0.00      0.00      0.00         2
#
# avg / total       1.00      1.00      1.00      2556
#  ================================================
# aid_related :
#              precision    recall  f1-score   support
#
#         0.0       0.65      0.90      0.75      1594
#         1.0       0.52      0.19      0.28       962
#
# avg / total       0.60      0.63      0.57      2556
#  ================================================
# medical_help :
#              precision    recall  f1-score   support
#
#         0.0       0.95      1.00      0.97      2425
#         1.0       0.00      0.00      0.00       131
#
# avg / total       0.90      0.95      0.92      2556
#  ================================================
# medical_products :
#              precision    recall  f1-score   support
#
#         0.0       0.97      1.00      0.98      2473
#         1.0       0.00      0.00      0.00        83
#
# avg / total       0.94      0.97      0.95      2556
#  ================================================
# search_and_rescue :
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99      2496
#         1.0       0.00      0.00      0.00        60
#
# avg / total       0.95      0.98      0.96      2556
#  ================================================
# security :
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99      2523
#         1.0       0.00      0.00      0.00        33
#
# avg / total       0.97      0.99      0.98      2556
#  ================================================
# military :
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      2548
#         1.0       0.00      0.00      0.00         8
#
# avg / total       0.99      1.00      1.00      2556
#  ================================================
# child_alone :
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      2556
#
# avg / total       1.00      1.00      1.00      2556
#  ================================================
# water :
#              precision    recall  f1-score   support
#
#         0.0       0.93      1.00      0.96      2367
#         1.0       0.00      0.00      0.00       189
#
# avg / total       0.86      0.93      0.89      2556
#  ================================================
# food :
#              precision    recall  f1-score   support
#
#         0.0       0.86      1.00      0.93      2209
#         1.0       0.00      0.00      0.00       347
#
# avg / total       0.75      0.86      0.80      2556
#  ================================================
# shelter :
#              precision    recall  f1-score   support
#
#         0.0       0.89      1.00      0.94      2274
#         1.0       0.18      0.01      0.01       282
#
# avg / total       0.81      0.89      0.84      2556
#  ================================================
# clothing :
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      1.00      2532
#         1.0       0.00      0.00      0.00        24
#
# avg / total       0.98      0.99      0.99      2556
#  ================================================
# money :
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      1.00      2531
#         1.0       0.00      0.00      0.00        25
#
# avg / total       0.98      0.99      0.99      2556
#  ================================================
# missing_people :
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99      2523
#         1.0       0.00      0.00      0.00        33
#
# avg / total       0.97      0.99      0.98      2556
#  ================================================
# refugees :
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99      2516
#         1.0       0.00      0.00      0.00        40
#
# avg / total       0.97      0.98      0.98      2556
#  ================================================
# death :
#              precision    recall  f1-score   support
#
#         0.0       0.97      1.00      0.99      2492
#         1.0       0.00      0.00      0.00        64
#
# avg / total       0.95      0.97      0.96      2556
#  ================================================
# other_aid :
#              precision    recall  f1-score   support
#
#         0.0       0.87      0.99      0.92      2215
#         1.0       0.06      0.00      0.01       341
#
# avg / total       0.76      0.86      0.80      2556
#  ================================================
# infrastructure_related :
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99      2494
#         1.0       0.00      0.00      0.00        62
#
# avg / total       0.95      0.98      0.96      2556
#  ================================================
# transport :
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99      2502
#         1.0       0.00      0.00      0.00        54
#
# avg / total       0.96      0.98      0.97      2556
#  ================================================
# buildings :
#              precision    recall  f1-score   support
#
#         0.0       0.96      1.00      0.98      2456
#         1.0       0.25      0.01      0.02       100
#
# avg / total       0.93      0.96      0.94      2556
#  ================================================
# electricity :
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      2544
#         1.0       0.00      0.00      0.00        12
#
# avg / total       0.99      0.99      0.99      2556
#  ================================================
# tools :
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      2548
#         1.0       0.00      0.00      0.00         8
#
# avg / total       0.99      1.00      1.00      2556
#  ================================================
# hospitals :
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      1.00      2543
#         1.0       0.00      0.00      0.00        13
#
# avg / total       0.99      0.99      0.99      2556
#  ================================================
# shops :
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      2551
#         1.0       0.00      0.00      0.00         5
#
# avg / total       1.00      1.00      1.00      2556
#  ================================================
# aid_centers :
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      1.00      2542
#         1.0       0.00      0.00      0.00        14
#
# avg / total       0.99      0.99      0.99      2556
#  ================================================
# other_infrastructure :
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99      2521
#         1.0       0.00      0.00      0.00        35
#
# avg / total       0.97      0.99      0.98      2556
#  ================================================
# weather_related :
#              precision    recall  f1-score   support
#
#         0.0       0.86      0.98      0.92      2193
#         1.0       0.27      0.04      0.06       363
#
# avg / total       0.78      0.85      0.80      2556
#  ================================================
# floods :
#              precision    recall  f1-score   support
#
#         0.0       0.97      1.00      0.99      2484
#         1.0       0.33      0.01      0.03        72
#
# avg / total       0.95      0.97      0.96      2556
#  ================================================
# storm :
#              precision    recall  f1-score   support
#
#         0.0       0.97      1.00      0.99      2488
#         1.0       1.00      0.01      0.03        68
#
# avg / total       0.97      0.97      0.96      2556
#  ================================================
# fire :
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      2544
#         1.0       0.00      0.00      0.00        12
#
# avg / total       0.99      1.00      0.99      2556
#  ================================================
# earthquake :
#              precision    recall  f1-score   support
#
#         0.0       0.92      1.00      0.96      2355
#         1.0       0.29      0.01      0.02       201
#
# avg / total       0.87      0.92      0.88      2556
#  ================================================
# cold :
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      1.00      2539
#         1.0       0.00      0.00      0.00        17
#
# avg / total       0.99      0.99      0.99      2556
#  ================================================
# other_weather :
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99      2511
#         1.0       0.00      0.00      0.00        45
#
# avg / total       0.97      0.98      0.97      2556
#  ================================================
# direct_report :
#              precision    recall  f1-score   support
#
#         0.0       0.69      0.96      0.80      1739
#         1.0       0.51      0.09      0.15       817
#
# avg / total       0.63      0.68      0.60      2556
#  ================================================
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
with open('MLclassifier.pkl', 'wb') as file:
    pickle.dump(optimised_model, file)

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
